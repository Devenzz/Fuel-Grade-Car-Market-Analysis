# %% [markdown]
# # EDA For Carzz Data

# %% [markdown]
# ### Importing required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Reading the csv file

# %%
df_cdp=pd.read_csv("New_final_cars.csv")
df_cdp.head(5)
# Out:
#   Brand_Name Model_Name Fuel_Type  Mileage Transmission_Type  Engine  \
# 0        BMW         M5    Petrol    49.75         Automatic    4395
# 1        BMW         X3    Petrol    14.86         Automatic    1998
# 2        BMW         Z4    Petrol     8.50  Manual/Automatic    2998
# 3        BMW   3 Series    Petrol    13.02         Automatic    2998
# 4        BMW         XM    Petrol    61.90         Automatic    4395
#
#    Seating_Capacity Country_Origin  Price(₹ Lakh) Car_Type
# 0                 5        Germany         201.00    Sedan
# 1                 5        Germany          72.65      SUV
# 2                 2        Germany          90.25    Sedan
# 3                 5        Germany          73.40    Sedan
# 4                 5        Germany         255.00    Sedan

# %%
df_ev=pd.read_csv("New_final_ev.csv")
df_ev.head(3)
# Out:
#   Brand_Name  Model_Name  Range_(km)  Efficiency_(Wh_per_km)  Weight_(kg)  \
# 0    Renault         Q90       245.0                   167.0       1555.0
# 1        Kia   e-Soul-X1       230.0                   170.0       1610.0
# 2       Opel  Phantom-X1       200.0                   232.0       1813.0
#
#    0_to_100_(sec)  Battery_(kWh)  FastCharge_(kW)  Cargo_(L)        Status  \
# 0            13.5           41.0             33.0      338.0  Discontinued
# 1             9.9           39.2             37.0      315.0     Presented
# 2            11.7           46.3             78.0      806.0  Discontinued
#
#   Transmission_Type   Car_Type  Price_(₹_Lakh) Country_Origin
# 0         Automatic      Coupe          29.180         France
# 1         Automatic  Hatchback         156.145    South Korea
# 2         Automatic      Sedan         198.220        Germany

# %%
df_combo=pd.read_csv("New_combo_final.csv")
df_combo.head(3)
# Out:
#       Brand_Name      Model_Name Fuel_Type  Price (₹ Lakh) Transmission_Type  \
# 0  Mercedes-Benz     Phantom-X91  Electric         128.095         Automatic
# 1         Toyota  Urban Cruiser     Petrol           8.705  Manual/Automatic
# 2           Tata    Harrier ZXi+    Diesel          19.800            Manual
#
#   Country_Origin Car_Type
# 0        Germany    Sedan
# 1          Japan      SUV
# 2          India      SUV

# %% [markdown]
# ### Data Information:

# %%
def show_info(*dfs):
    for name, df in zip(['df_cdp', 'df_ev', 'df_combo'], dfs):
        print(f"\n🔹 {name} Info:")
        df.info()
        print("-" * 80)

show_info(df_cdp, df_ev, df_combo)
# Out:
# 🔹 df_cdp Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331 entries, 0 to 330
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Brand_Name         331 non-null    object
#  1   Model_Name         331 non-null    object
#  2   Fuel_Type          331 non-null    object
#  3   Mileage            331 non-null    float64
#  4   Transmission_Type  331 non-null    object
#  5   Engine             331 non-null    int64
#  6   Seating_Capacity   331 non-null    int64
#  7   Country_Origin     331 non-null    object
#  8   Price(₹ Lakh)      331 non-null    float64
#  9   Car_Type           331 non-null    object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 26.0+ KB
# --------------------------------------------------------------------------------
#
# 🔹 df_ev Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 14 columns):
# ...

# %% [markdown]
# # Observation for df_car
#
# - There are 3 numeric columns and the remaining 7 columns are of type object.
#
# - The numeric columns are: Price_(₹_Lakh), Mileage_or_Range, Engine_or_BHP
#
# - The object columns are: Brand_Name, Model_Name, Fuel_Type, Transmission_Type, Seating_Capacity, Country_Origin, Car_Type

# %% [markdown]
# # Observation for df_ev
#
# - There are 8 numeric columns and the remaining 6 columns are of type object.
#
# - The numeric columns are: Range_(km), Efficiency_(Wh_per_km), Weight_(kg), 0_to_100_(sec), Battery_(kWh), FastCharge_(kW), Cargo_(L), Price_(₹_Lakh)
#
# - The object columns are: Brand_Name, Model_Name, Status, Transmission_Type, Car_Type, Country_Origin

# %% [markdown]
# # Observation for df_combo
#
# - There are 1 numeric column and the remaining 5 columns are of type object.
#
# - The numeric column is: Price_in_Lakh
#
# - The object columns are: Brand_Name, Model_Name, Fuel_Type, Transmission_Type, Country_Origin

# %% [markdown]
# ## Checking the shape of data:

# %%
print(df_cdp.shape)
print(df_ev.shape)
print(df_combo.shape)
# Out:
# (331, 10)
# (400, 14)
# (731, 7)

# %% [markdown]
# ##  Observation:
#
# - The df_car dataset contains 331 rows and 10 columns.
#
# - The df_ev dataset contains 400 rows and 14 columns.
#
# - The df_combo dataset contains 731 rows and 7 columns.

# %% [markdown]
# ### Checking the columns of data:

# %%
print(df_cdp.columns)
print()
print(df_ev.columns)
print()
print(df_combo.columns)
# Out:
# Index(['Brand_Name', 'Model_Name', 'Fuel_Type', 'Mileage', 'Transmission_Type',
#        'Engine', 'Seating_Capacity', 'Country_Origin', 'Price(₹ Lakh)',
#        'Car_Type'],
#       dtype='object')
#
# Index(['Brand_Name', 'Model_Name', 'Range_(km)', 'Efficiency_(Wh_per_km)',
#        'Weight_(kg)', '0_to_100_(sec)', 'Battery_(kWh)', 'FastCharge_(kW)',
#        'Cargo_(L)', 'Status', 'Transmission_Type', 'Car_Type',
#        'Price_(₹_Lakh)', 'Country_Origin'],
#       dtype='object')
#
# Index(['Brand_Name', 'Model_Name', 'Fuel_Type', 'Price (₹ Lakh)',
#        'Transmission_Type', 'Country_Origin', 'Car_Type'],
#       dtype='object')

# %% [markdown]
# ## Checking the duplicates:

# %%
print(df_cdp.duplicated().sum())
print(df_ev.duplicated().sum())
print(df_combo.duplicated().sum())
# Out:
# 0
# 0
# 0

# %% [markdown]
# ## Observation:
# - There are no duplicates values in the dataset

# %% [markdown]
# ## Checking the null values:

# %%
print(df_cdp.isnull().sum())
print()
print(df_ev.isnull().sum())
print()
print(df_combo.isnull().sum())
# Out:
# Brand_Name           0
# Model_Name           0
# Fuel_Type            0
# Mileage              0
# Transmission_Type    0
# Engine               0
# Seating_Capacity     0
# Country_Origin       0
# Price(₹ Lakh)        0
# Car_Type             0
# dtype: int64
#
# Brand_Name                0
# Model_Name                0
# Range_(km)                0
# Efficiency_(Wh_per_km)    0
# Weight_(kg)               0
# 0_to_100_(sec)            0
# Battery_(kWh)             0
# FastCharge_(kW)           0
# Cargo_(L)                 0
# Status                    0
# Transmission_Type         0
# Car_Type                  0
# Price_(₹_Lakh)            0
# Country_Origin            0
# dtype: int64
#
# Brand_Name           0
# Model_Name           0
# Fuel_Type            0
# Price (₹ Lakh)       0
# Transmission_Type    0
# Country_Origin       0
# Car_Type             0
# dtype: int64

# %% [markdown]
# ## Observation:
# - There are no null values in the dataset

# %% [markdown]
# ## Checking the description of the data:

# %%
df_cdp.describe()
# Out:
#           Mileage       Engine  Seating_Capacity  Price(₹ Lakh)
# count  331.000000   331.000000        331.000000     331.000000
# mean    18.191420  1902.132931          5.265861      50.034184
# std      6.071375   867.326820          1.003938      87.815416
# min      6.800000   796.000000          2.000000       4.155000
# 25%     14.305000  1248.000000          5.000000       8.935000
# 50%     18.300000  1498.000000          5.000000      14.960000
# 75%     22.005000  2154.000000          5.000000      48.112500
# max     61.900000  6750.000000          8.000000     795.000000

# %%
df_ev.describe()
# Out:
#        Range_(km)  Efficiency_(Wh_per_km)  Weight_(kg)  0_to_100_(sec)  \
# count  400.000000              400.000000   400.000000      400.000000
# mean   371.287500              193.327500  2103.617500        7.352250
# std    115.336621               29.393455   393.796954        3.140853
# min     85.000000              109.000000  1012.000000        2.200000
# 25%    293.750000              171.000000  1825.000000        4.875000
# 50%    377.500000              188.000000  2161.000000        6.950000
# 75%    456.250000              206.000000  2395.000000        8.800000
# max    720.000000              294.000000  3085.000000       22.400000
#
#        Battery_(kWh)  FastCharge_(kW)    Cargo_(L)  Price_(₹_Lakh)
# count     400.000000       400.000000   400.000000      400.000000
# mean       71.384750       115.205000   529.255000      132.940612
# std        22.802477        57.379779   229.888738       80.852667
# ...

# %%
df_combo.describe()
# Out:
#        Price (₹ Lakh)
# count      731.000000
# mean        95.400219
# std         93.618806
# min          4.155000
# 25%         15.410000
# 50%         72.150000
# 75%        141.592500
# max        795.000000

# %% [markdown]
# ## Renaming the column

# %% [markdown]
# df _car.rename(columns={'brand': 'Brand_Name','model': 'Model_Name','fuel_type': 'Fuel_Type','mileage/ range': 'Mileage','transmission': 'Transmission_Type',
#                        'engine_cc/bhp': 'Engine', 'seating_capacity': 'Seating_Capacity','country_origin': 'Country_Origin','Price_in_Lakh': 'Price(₹ Lakh)',
#                        'car_type': 'Car_Type'}, inplace=True)
#
# print("Columns renamed successfully!")

# %% [markdown]
# df _ev.rename(columns={'brand': 'Brand_Name','model': 'Model_Name','Range_km': 'Range_(km)','Efficiency_Wh_per_km': 'Efficiency_(Wh_per_km)','Weight_kg': 'Weight_(kg)',
#     'Zero_to_Hundred_sec': '0_to_100_(sec)', 'Battery_kWh': 'Battery_(kWh)','Fastcharge_kW': 'FastCharge_(kW)','Cargo_L': 'Cargo_(L)',
#     'status': 'Status', 'transmission': 'Transmission_Type', 'car_type': 'Car_Type','Price_in_Lakh': 'Price_(₹_Lakh)','country_origin': 'Country_Origin'}, inplace=True)
#
# print(" Columns renamed successfully for df_ev!")

# %% [markdown]
# df _combo.rename(columns={'brand': 'Brand_Name','model': 'Model_Name','fuel_type': 'Fuel_Type','Price_in_Lakh': 'Price (₹ Lakh)','transmission': 'Transmission_Type',
#     'country_origin': 'Country_Origin','car_type': 'Car_Type'}, inplace=True)
#
# print(" Columns renamed successfully for df_combo!")

# %% [markdown]
# # Visualization:
# - We are going to visualize the data in to two formats or in two types that are:

# %% [markdown]
# # 1. Univariate analysis:
# - The univarient analysis is mostly used to examine the one variable or one column at a time.
# - By this we can understand the distribution or the central tendency and the spread of the data.

# %% [markdown]
# ## Distribution of car prices in the dataset

# %%
plt.figure(figsize=(10,6))
ax=sns.histplot(df_cdp['Price(₹ Lakh)'], bins=30, kde=True)
for i in ax.containers:
    plt.bar_label(i)
plt.title('Distribution of Car Prices')
plt.xlabel('Price (₹ Lakh)')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# # Insights:
# - Identify the most common price range for cars.
# - Detect luxury outliers and compare mid-range car segments.

# %%
max_price = df_cdp['Price(₹ Lakh)'].max()
max_row = df_cdp.loc[df_cdp['Price(₹ Lakh)'] == max_price]
max_row
# Out:
#       Brand_Name Model_Name Fuel_Type  Mileage Transmission_Type  Engine  \
# 226  Rolls-Royce      Ghost    Petrol      6.8         Automatic    6750
#
#      Seating_Capacity Country_Origin  Price(₹ Lakh) Car_Type
# 226                 4             UK          795.0    Sedan

# %% [markdown]
# ## Distribution of engine capacities across cars

# %%
plt.figure(figsize=(10,6))
ax=sns.histplot(df_cdp['Engine'], bins=25, color='orange', kde=True)
for i in ax.containers:
    plt.bar_label(i)
plt.title('Distribution of Engine Capacity (CC)')
plt.xlabel('Engine (CC)')
plt.ylabel('Count')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# # Insights:
# - Observe the most frequent engine range.
# - Check if high-performance engines (3000+ cc) are rare or common.

# %%
max_price = df_cdp['Engine'].max()
max_row = df_cdp.loc[df_cdp['Engine'] == max_price]
max_row
# Out:
#       Brand_Name Model_Name Fuel_Type  Mileage Transmission_Type  Engine  \
# 226  Rolls-Royce      Ghost    Petrol      6.8         Automatic    6750
#
#      Seating_Capacity Country_Origin  Price(₹ Lakh) Car_Type
# 226                 4             UK          795.0    Sedan

# %% [markdown]
# ## Dominant fuel type in the Indian car market

# %%
plt.figure(figsize=(7,7))
fuel_type = df_cdp['Fuel_Type'].value_counts()

explode = [0.1 if i == fuel_type.idxmax() else 0 for i in fuel_type.index]
plt.pie(
    fuel_type,
    labels=fuel_type.index,
    autopct='%1.0f%%',
    startangle=140,
    shadow=True,
    colors=sns.color_palette('pastel', len(fuel_type)),
    explode=explode
)
plt.title('Fuel Type Market Share')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Insights:
# - Highlights the dominance of Petrol or Diesel cars.
# - Helps understand adoption of CNG, Hybrid, or Electric options.
# - The exploded slice marks the most common fuel type.

# %% [markdown]
# ## Explore the distribution of mileage among cars

# %%
plt.figure(figsize=(10,6))
ax=sns.histplot(df_cdp['Mileage'], bins=30, kde=True, color='coral')
for i in ax.containers:
    plt.bar_label(i)
plt.title('Mileage Frequency Distribution')
plt.xlabel('Mileage (km/l)')
plt.ylabel('Number of Cars')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# # Insights:
# - The graph shows that most cars deliver moderate mileage, indicating a balance between fuel efficiency and engine performance.
# - High-mileage cars are fewer, suggesting limited options for highly fuel-efficient models.
# - The distribution is slightly right-skewed, meaning cars with lower mileage are more common in the market.

# %% [markdown]
# ## Distribution of different car types in the dataset

# %%
plt.figure(figsize=(9,5))
ax=sns.countplot(x='Car_Type', data=df_cdp, palette='Set2')
for i in ax.containers:
    plt.bar_label(i)
plt.title('Count of Cars by Type')
plt.xlabel('Car Type')
plt.ylabel('Number of Cars')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# # Insights:
# - Displays which body styles (SUV, Sedan, Hatchback, etc.) dominate.
# - Easier to compare visually than pie chart when many categories exist.
# - Helps detect less common car segments.

# %% [markdown]
# # 2. Bivariate Analysis
#
# - The bivarient analysis is used to examine the relationship between the two variables at a time.
# - It helps us to understand that how one variable influences or corelates with another , whether the move together, diverge, or show some patterns of dependency.

# %% [markdown]
# ## Compare car prices vs mileage across fuel types

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='Mileage', y='Price(₹ Lakh)', hue='Fuel_Type', data=df_cdp, s=70)
plt.title('Price vs Mileage across Fuel Types')
plt.xlabel('Mileage (km/l)')
plt.ylabel('Price (₹ Lakh)')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# # Insights:
# - Check if high-mileage cars are cheaper or costlier.
# - Compare efficiency-price tradeoffs among different fuel types.

# %% [markdown]
#  ## Examine how seating capacity influences the price.

# %%
plt.figure(figsize=(9,5))
sns.boxplot(x='Seating_Capacity', y='Price(₹ Lakh)', data=df_cdp, palette='pastel')
plt.title('Price Distribution by Seating Capacity')
plt.xlabel('Seating Capacity')
plt.ylabel('Price (₹ Lakh)')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# # Insights:
# - See how car size (number of seats) affects pricing.
# - Larger SUVs likely have higher price medians.

# %% [markdown]
# ## Investigate the relation between engine capacity and mileage

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='Engine', y='Mileage', data=df_cdp, color='purple', s=70)
plt.title('Relation between Engine Capacity and Mileage')
plt.xlabel('Engine (CC)')
plt.ylabel('Mileage (km/l)')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# # Insights:
# - Expect inverse correlation: larger engines → lower mileage.
# - Outliers may indicate hybrid or performance-tuned engines.

# %% [markdown]
# ## Average Price Comparison: Transmission Type vs Fuel Type

# %%
plt.figure(figsize=(10,5))
data = df_cdp if 'df_cdp' in globals() else df
ax=sns.barplot(x='Transmission_Type',y='Price(₹ Lakh)',hue='Fuel_Type',data=data,palette='Set2',errorbar=None)
for i in ax.containers:
    plt.bar_label(i)
plt.title('Average Price by Transmission Type and Fuel Type')
plt.xlabel('Transmission Type')
plt.ylabel('Average Price (₹ Lakh)')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.legend(title='Fuel Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Insights:
# - Highlights which fuel–transmission combinations are more expensive on average.
# - Automatic Petrol cars often cost more than Manual variants.
# - Diesel models may have narrower price gaps between transmission types.
# - Easy to interpret and visually balanced for categorical comparison.

# %% [markdown]
# ## Average Price by Car Type

# %%
plt.figure(figsize=(9,5))
avg_price = df_cdp.groupby('Car_Type')['Price(₹ Lakh)'].mean().sort_values(ascending=False)
ax=sns.barplot(x=avg_price.index, y=avg_price.values, palette='Set2')
for i in ax.containers:
    plt.bar_label(i)
plt.title('Average Price by Car Type')
plt.xlabel('Car Type')
plt.ylabel('Average Price (₹ Lakh)')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# # Insights:
# - SUV and Sedan have higher average prices.
# - Hatchbacks and Compact cars are most affordable.
# - Clearly shows which body segment dominates premium pricing.

# %% [markdown]
# ## -----------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 1. Univariate analysis:
# - The univarient analysis is mostly used to examine the one variable or one column at a time.
# - By this we can understand the distribution or the central tendency and the spread of the data.

# %% [markdown]
# ## Distribution of EV prices across market segments

# %%
plt.figure(figsize=(10,6))
ax=sns.histplot(df_ev['Price_(₹_Lakh)'], bins=30, kde=True, color='teal')
for i in ax.containers:
    plt.bar_label(i)
plt.title('Distribution of EV Prices')
plt.xlabel('Price (₹ Lakh)')
plt.ylabel('Count')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# #  Insights:
# - Most EVs cluster in mid-range price segments.
# - Outliers show premium electric vehicles.

# %% [markdown]
# ## Distribution of EV range per full charge

# %%
range_bins = [0, 200, 300, 400, 500, 600, 700, df_ev['Range_(km)'].max()]
range_labels = ['<200', '200–300', '300–400', '400–500', '500–600', '600–700', '>700']
df_ev['Range_Category'] = pd.cut(df_ev['Range_(km)'], bins=range_bins, labels=range_labels, include_lowest=True)

# Count how many EVs fall into each range group
range_counts = df_ev['Range_Category'].value_counts().sort_index()
plt.figure(figsize=(12,5))
ax = sns.barplot(x=range_counts.index, y=range_counts.values, palette='Blues_r', width=0.7)
for i in ax.containers:
    ax.bar_label(i)
plt.title('Distribution of EVs by Range Category')
plt.xlabel('Range (km)')
plt.ylabel('Number of EV Models')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Insights:
# - Most EVs fall between 300–500 km range.
# - Very few models exceed 600+ km, showing rarity of ultra-long-range EVs.
# - The labeled bars make it super easy to interpret at a glance.

# %% [markdown]
# ## Distribution of battery capacity across EV models

# %%
plt.figure(figsize=(9,5))
sns.boxplot(y='Battery_(kWh)', data=df_ev, color='lightgreen')
plt.title('Distribution of Battery Capacity')
plt.ylabel('Battery (kWh)')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# # Insights:
# - Median battery capacity shows standard EV category range.
# - Outliers represent high-performance models.

# %% [markdown]
# ## Performance variation based on EV acceleration (0–100 km/h)

# %%
plt.figure(figsize=(9,5))
ax=sns.histplot(df_ev['0_to_100_(sec)'], bins=20, color='orange', kde=True)
for i in ax.containers:
    plt.bar_label(i)
plt.title('Acceleration (0–100 km/h) Distribution')
plt.xlabel('Seconds (0–100)')
plt.ylabel('Number of Cars')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# # Insights:
# - Insights:Fastest EVs accelerate below 5 seconds.
# - Average models take around 8–10 seconds.

# %% [markdown]
# ## Top countries by EV model production

# %%
plt.figure(figsize=(7,7))
country = df_ev['Country_Origin'].value_counts().head(5)
explode = [0.1 if i == country.idxmax() else 0 for i in country.index]

plt.pie(country,labels=country.index, autopct='%1.0f%%', startangle=140, colors=sns.color_palette('pastel', len(country)),
        explode=explode, shadow=True)
plt.title('Top 5 Countries by EV Models')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Insights:
# - Shows which country leads EV manufacturing.
# - Exploded slice marks the top contributor.

# %% [markdown]
# ## Dominant EV body types in the market

# %%
plt.figure(figsize=(9,5))
top6_types = df_ev['Car_Type'].value_counts().head(6).index
order = df_ev[df_ev['Car_Type'].isin(top6_types)]['Car_Type'].value_counts().sort_values(ascending=True).index

ax = sns.countplot(y='Car_Type', data=df_ev[df_ev['Car_Type'].isin(top6_types)],
                   order=order, palette='viridis')
for i in ax.containers:
    plt.bar_label(i)
plt.title('Count of Top 6 EV Car Types (Low to High)', fontsize=13, weight='bold')
plt.xlabel('Number of Models')
plt.ylabel('Car Type')
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Insights:
# - Hatchbacks and Coupes have the fewest EV models available.
# - SUVs and Sedans dominate the market, indicating higher consumer demand.
# - The clear ranking shows which car body styles are most prioritized by manufacturers.

# %% [markdown]
# # 2. Bivariate analysis

# %% [markdown]
# ## Calculate top 5 brands with highest average range

# %%
top10_brands = df_ev.groupby('Brand_Name')['Range_(km)'].mean().sort_values(ascending=False).head(5)
plt.figure(figsize=(10,5))
ax = sns.barplot(x=top10_brands.values, y=top10_brands.index, palette='viridis')
for i in ax.containers:
    plt.bar_label(i)
plt.title('Top 5 Brands by Average EV Range', fontsize=13, weight='bold')
plt.xlabel('Average Range (km)')
plt.ylabel('Brand Name')
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Insights:
# - Lucid offers the highest average range of about 615 km.
# - Lightyear and Lotus also provide strong range performance.
# - Tesla ranks lower, showing rising competition in EV range.

# %% [markdown]
# ## Impact of battery capacity on EV range across countries

# %%
plt.figure(figsize=(9,5))
sns.scatterplot(x='Battery_(kWh)', y='Range_(km)', hue='Country_Origin', data=df_ev, s=70)
plt.title('Battery Capacity vs Range by Country')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# # Insights:
# - Strong correlation: higher battery = more range.
# - Country color clusters highlight design differences.

# %% [markdown]
# ## Calculate average efficiency for each car type

# %%
efficiency_by_type = df_ev.groupby('Car_Type')['Efficiency_(Wh_per_km)'].mean().sort_values(ascending=False).reset_index()

plt.figure(figsize=(10,5))
ax = sns.barplot(x='Car_Type', y='Efficiency_(Wh_per_km)', data=efficiency_by_type, palette='viridis')
for i in ax.containers:
    plt.bar_label(i)
plt.title('Average Efficiency by Car Type')
plt.xlabel('Car Type')
plt.ylabel('Average Efficiency')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Insights:
# - Shows which car type consumes more energy per km.
# - SUVs and Sedans often appear at the top (less efficient due to weight).
# - Hatchbacks or smaller cars are the most energy-efficient.

# %% [markdown]
# ## Calculate top 10 brands by average range

# %%
brand_range = df_ev.groupby('Brand_Name')['Range_(km)'].mean().sort_values(ascending=False).head(10).reset_index()

plt.figure(figsize=(13,5))
ax = sns.barplot(data=brand_range, x='Brand_Name',y='Range_(km)',hue='Brand_Name',palette='viridis',legend=False)
for i in ax.containers:
    plt.bar_label(i)
plt.title('Top 10 Brands by Average EV Range')
plt.xlabel('Brand Name')
plt.ylabel('Average Range (km)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Insights:
# - Instantly shows which brands lead in EV range capability.
# - The labels make values directly visible — no need to estimate from bars.
# - Great for clean presentations or dashboards.

# %% [markdown]
# ## Relationship between fast charging power and price.

# %%
plt.figure(figsize=(9,5))
sns.scatterplot(x='FastCharge_(kW)', y='Price_(₹_Lakh)', hue='Country_Origin', data=df_ev, s=70)
plt.title('Fast Charging Power vs Price')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# # Insights:
# - Faster charging models often come at premium prices.
# - Shows technological advancement by country.

# %% [markdown]
# ## Evaluate how acceleration (0–100 sec) correlates with EV price across car types.

# %%
# Create acceleration categories
df_ev['Accel_Category'] = pd.cut(df_ev['0_to_100_(sec)'],
                                 bins=[0, 5, 8, 12, df_ev['0_to_100_(sec)'].max()],
                                 labels=['Very Fast', 'Fast', 'Moderate', 'Slow'])

plt.figure(figsize=(9,5))
sns.boxplot(x='Accel_Category', y='Price_(₹_Lakh)', data=df_ev, palette='Set2')
plt.title('Price Distribution by Acceleration Category')
plt.xlabel('Acceleration (0–100 km/h) Category')
plt.ylabel('Price (₹ Lakh)')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# # Insights:
# - Very Fast EVs (≤5 sec) clearly sit in the premium price range.
# - Moderate and Slow EVs dominate the affordable segment.
# - Easier to read than a scatter — shows spread, median, and outliers cleanly.

# %% [markdown]
# #  Multivariate analysis:

# %% [markdown]
# ##  Average Price Comparison by Fuel Type and Transmission Type

# %%
plt.figure(figsize=(10,5))
avg_price = df_combo.groupby(['Fuel_Type', 'Transmission_Type'])['Price (₹ Lakh)'].mean().reset_index()
ax = sns.barplot(x='Fuel_Type', y='Price (₹ Lakh)', hue='Transmission_Type', data=avg_price, palette='viridis')
for i in ax.containers:
    plt.bar_label(i)
plt.title('Average Car Price by Fuel Type and Transmission Type', fontsize=13, weight='bold')
plt.xlabel('Fuel Type')
plt.ylabel('Average Price (₹ Lakh)')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Insights:
# - Automatic variants are costlier than manual ones in almost every fuel type.
# - Electric and hybrid vehicles show the highest average prices.
# - The grouped bars clearly reveal price segmentation by fuel and transmission choice

# %% [markdown]
# ## Top 5 Countries with Most Models by Fuel Type

# %%
plt.figure(figsize=(10,5))
top5 = df_combo['Country_Origin'].value_counts().head(5).index
ax = sns.countplot(y='Country_Origin', hue='Fuel_Type', data=df_combo[df_combo['Country_Origin'].isin(top5)], palette='mako')
for i in ax.containers:
    plt.bar_label(i)
plt.title('Top 5 Countries by Model Count and Fuel Type')
plt.xlabel('Number of Models')
plt.ylabel('Country')
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Insights:
# - Germany and Japan have the broadest variety of fuel types and car models.
# - India primarily focuses on fuel-based vehicles with growing EV entries.
# - This visualization clearly compares each country's contribution by energy type.

# %% [markdown]
# ## Top 5 Brands: Price Comparison by Fuel Type and Car Type

# %%
plt.figure(figsize=(10,6))
top5 = [b for b in df_combo['Brand_Name'].value_counts().index if b != 'Maruti Suzuki'][:5]
ax = sns.barplot(y='Brand_Name', x='Price (₹ Lakh)', hue='Fuel_Type',
                 data=df_combo[df_combo['Brand_Name'].isin(top5)],
                 estimator='mean', errorbar=None, palette='viridis')
for i in ax.containers:
    plt.bar_label(i)
plt.title('Top 5 Premium Brands: Avg Price by Fuel Type')
plt.xlabel('Average Price (₹ Lakh)')
plt.ylabel('Brand Name')
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Insights:
# - Shows fuel-based price diversity across major brands.
# - EV brands like BMW and Mercedes-Benz, toyota lead in top-tier pricing.
# - Helps detect brands with wider fuel portfolios and pricing flexibility.

# %% [markdown]
# ## Impact of country, car type & transmission on market pricing

# %%
plt.figure(figsize=(10,8))
top5_types = df_combo['Car_Type'].value_counts().head(5).index
top5_countries = df_combo['Country_Origin'].value_counts().head(5).index

ax = sns.barplot(x='Car_Type', y='Price (₹ Lakh)', hue='Country_Origin',
                 data=df_combo[df_combo['Car_Type'].isin(top5_types) & df_combo['Country_Origin'].isin(top5_countries)],
                 estimator='mean', errorbar=None, palette='viridis')
for i in ax.containers:
    plt.bar_label(i,rotation=90)
plt.title('Average Price of Top 5 Car Types across Top 5 Countries')
plt.xlabel('Car Type')
plt.ylabel('Average Price (₹ Lakh)')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Insights:
# - SUVs and Sedans remain the most expensive across all top-producing countries.
# - Germany leads in high-priced luxury segments, while India dominates the affordable range.
# - The combination of top 5 countries and car types highlights global pricing tiers in a simple, readable view.

# %% [markdown]
# ## Market presence by fuel type among top 5 car type

# %%
plt.figure(figsize=(10,5))
top5_types = df_combo['Car_Type'].value_counts().head(5).index
ax = sns.countplot(y='Fuel_Type', hue='Car_Type',
                   data=df_combo[df_combo['Car_Type'].isin(top5_types)],
                   palette='viridis')
for i in ax.containers:
    plt.bar_label(i)
plt.title('Market Presence by Fuel Type (Top 5 Car Types)', fontsize=13, weight='bold')
plt.xlabel('Number of Models')
plt.ylabel('Fuel Type')
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Insights:
# - Petrol and Diesel dominate total model count across top car types.
# - SUVs and Sedans appear most frequently across fuel categories.
# - The horizontal layout makes brand-wise and category-wise comparisons clearer and cleaner.
